# %% [markdown]
# ### Testing the downloader

# %%
from youmirror.downloader import *
import pytube.cipher
from pytube import YouTube
yt = YouTube("https://www.youtube.com/watch?v=Pa_HT9vQiLw")

# %%
stream = yt.streams.get_highest_resolution()
# Out:
# ---------------------------------------------------------------------------
# RegexMatchError                           Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/youmirror-1iwEkUPf-py3.9/lib/python3.9/site-packages/pytube/__main__.py:181, in YouTube.fmt_streams(self)
#     <a href='file:///home/user/.cache/pypoetry/virtualenvs/youmirror-1iwEkUPf-py3.9/lib/python3.9/site-packages/pytube/__main__.py?line=179'>180</a> try:
# --> <a href='file:///home/user/.cache/pypoetry/virtualenvs/youmirror-1iwEkUPf-py3.9/lib/python3.9/site-packages/pytube/__main__.py?line=180'>181</a>     extract.apply_signature(stream_manifest, self.vid_info, self.js)
#     <a href='file:///home/user/.cache/pypoetry/virtualenvs/youmirror-1iwEkUPf-py3.9/lib/python3.9/site-packages/pytube/__main__.py?line=181'>182</a> except exceptions.ExtractError:
# ...
