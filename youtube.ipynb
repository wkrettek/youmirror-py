# %%
from pytube import YouTube, Playlist, Stream, Channel
from typing import Union

# %%
well = type(playlist) in [Channel, Playlist]
print(well)
# Out:
# True

# %% [markdown]
# ## Videos

# %%
yt = YouTube('https://www.youtube.com/watch?v=pn4XSDnaiPY&list=PLbpi6ZahtOH52gc6K5nH46dbD55DxH3a1')
print(yt.title)
print(yt.watch_url)
print(yt.thumbnail_url)
print(yt.channel_id)
print(yt.channel_url)
print(yt.author)
print(yt.video_id)
# Out:
# Non-Fungible Planet | YouTube
# https://youtube.com/watch?v=pn4XSDnaiPY
# https://i.ytimg.com/vi/pn4XSDnaiPY/sddefault.jpg
# UCBR8-60-B28hp2BmDPdntcQ
# https://www.youtube.com/channel/UCBR8-60-B28hp2BmDPdntcQ
# YouTube
# pn4XSDnaiPY

# %% [markdown]
# ## Playlists

# %%
playlist = Playlist("https://www.youtube.com/watch?v=pn4XSDnaiPY&list=PLbpi6ZahtOH52gc6K5nH46dbD55DxH3a1")
playlist.url_generator()
print(playlist.title)
print(playlist.owner)
print(playlist.owner_id)
print(playlist.description)
print("Playlist id", playlist.playlist_id)
print("Playlist url", playlist.playlist_url)
for url in playlist.url_generator():
    print(url)
# Out:
# Non-Fungible Planet from YouTube
# YouTube
# UCBR8-60-B28hp2BmDPdntcQ
# Celebrate Earth Day with YouTube and your favorite Creators as we explore this Non-Fungible Planet we call home.
# After all, there’s nothing more valuable in the world than the world itself.
# Playlist id PLbpi6ZahtOH52gc6K5nH46dbD55DxH3a1
# Playlist url https://www.youtube.com/playlist?list=PLbpi6ZahtOH52gc6K5nH46dbD55DxH3a1
# https://www.youtube.com/watch?v=pn4XSDnaiPY
# https://www.youtube.com/watch?v=fiYvkBkdlOQ
# https://www.youtube.com/watch?v=mdecshXNmgA
# https://www.youtube.com/watch?v=UzfCgcgrOH8
# https://www.youtube.com/watch?v=bIJAiJk97aw
# https://www.youtube.com/watch?v=UfUawgZKKoE
# https://www.youtube.com/watch?v=qqpgezEiup0

# %% [markdown]
# ## Channels

# %%
# Need to do some weird stuff to track channels because 
# https://www.youtube.com/channel/UC-9-kyTW8ZkZNDHQJ6FgpwQ
# is different from 
# https://www.youtube.com/c/UC-9-kyTW8ZkZNDHQJ6FgpwQ
# But they have the same id!!!
# ---- Going to use the uri ----

# Maybe track the prefix?
channel = Channel("https://www.youtube.com/user/videogamedunkey")
print(channel.channel_name)
print(channel.channel_id)
print(channel.vanity_url)
print(channel.channel_uri)  # Okay the key is using the uri, not the vanity url
print(len(channel.video_urls))
# Out:
# videogamedunkey
# UCsvn_Po0SmunchJYOWpOxMg
# http://www.youtube.com/user/videogamedunkey
# /user/videogamedunkey
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/warrenkrettek/Documents/projects/youmirror/youtube.ipynb Cell 7' in <cell line: 14>()
#      <a href='vscode-notebook-cell:/Users/warrenkrettek/Documents/projects/youmirror/youtube.ipynb#ch0000006?line=11'>12</a> print(channel.vanity_url)
#      <a href='vscode-notebook-cell:/Users/warrenkrettek/Documents/projects/youmirror/youtube.ipynb#ch0000006?line=12'>13</a> print(channel.channel_uri)  # Okay the key is using the uri, not the vanity url
# ---> <a href='vscode-notebook-cell:/Users/warrenkrettek/Documents/projects/youmirror/youtube.ipynb#ch0000006?line=13'>14</a> print(len(channel.video_urls))
#
# File ~/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py:89, in DeferredGeneratorList.__len__(self)
#      <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py?line=86'>87</a> def __len__(self) -> int:
#      <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py?line=87'>88</a>     """Return length of list of all items."""
# ---> <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py?line=88'>89</a>     self.generate_all()
#      <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py?line=89'>90</a>     return len(self._elements)
#
# File ~/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py:105, in DeferredGeneratorList.generate_all(self)
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py?line=102'>103</a> while True:
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py?line=103'>104</a>     try:
# --> <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py?line=104'>105</a>         next_item = next(self.gen)
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py?line=105'>106</a>     except StopIteration:
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/helpers.py?line=106'>107</a>         break
#
# File ~/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py:281, in Playlist.url_generator(self)
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=275'>276</a> def url_generator(self):
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=276'>277</a>     """Generator that yields video URLs.
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=277'>278</a>
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=278'>279</a>     :Yields: Video URLs
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=279'>280</a>     """
# --> <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=280'>281</a>     for page in self._paginate():
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=281'>282</a>         for video in page:
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=282'>283</a>             yield self._video_url(video)
#
# File ~/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py:142, in Playlist._paginate(self, until_watch_id)
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=138'>139</a> logger.debug("load more url: %s", load_more_url)
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=139'>140</a> # requesting the next page of videos with the url generated from the
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=140'>141</a> # previous page, needs to be a post
# --> <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=141'>142</a> req = request.post(load_more_url, extra_headers=headers, data=data)
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=142'>143</a> # extract up to 100 songs from the page loaded
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=143'>144</a> # returns another continuation if more videos are available
#     <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/contrib/playlist.py?line=144'>145</a> videos_urls, continuation = self._extract_videos(req)
#
# File ~/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/request.py:85, in post(url, extra_headers, data, timeout)
#      <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/request.py?line=77'>78</a> extra_headers.update({"Content-Type": "application/json"})
#      <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/request.py?line=78'>79</a> response = _execute_request(
#      <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/request.py?line=79'>80</a>     url,
#      <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/request.py?line=80'>81</a>     headers=extra_headers,
#      <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/request.py?line=81'>82</a>     data=data,
#      <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/request.py?line=82'>83</a>     timeout=timeout
#      <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/request.py?line=83'>84</a> )
# ---> <a href='file:///Users/warrenkrettek/Library/Caches/pypoetry/virtualenvs/youmirror-DiMKVoJk-py3.9/lib/python3.9/site-packages/pytube/request.py?line=84'>85</a> return response.read().decode("utf-8")
#
# File /opt/homebrew/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:470, in HTTPResponse.read(self, amt)
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=464'>465</a> else:
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=465'>466</a>     # Amount is not given (unbounded read) so we must check self.length
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=466'>467</a>     # and self.chunked
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=468'>469</a>     if self.chunked:
# --> <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=469'>470</a>         return self._readall_chunked()
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=471'>472</a>     if self.length is None:
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=472'>473</a>         s = self.fp.read()
#
# File /opt/homebrew/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:580, in HTTPResponse._readall_chunked(self)
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=577'>578</a>     if chunk_left is None:
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=578'>579</a>         break
# --> <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=579'>580</a>     value.append(self._safe_read(chunk_left))
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=580'>581</a>     self.chunk_left = 0
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=581'>582</a> return b''.join(value)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:626, in HTTPResponse._safe_read(self, amt)
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=623'>624</a> s = []
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=624'>625</a> while amt > 0:
# --> <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=625'>626</a>     chunk = self.fp.read(min(amt, MAXAMOUNT))
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=626'>627</a>     if not chunk:
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py?line=627'>628</a>         raise IncompleteRead(b''.join(s), amt)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py?line=701'>702</a> while True:
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py?line=702'>703</a>     try:
# --> <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py?line=703'>704</a>         return self._sock.recv_into(b)
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py?line=704'>705</a>     except timeout:
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py?line=705'>706</a>         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1236'>1237</a>     if flags != 0:
#    <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1237'>1238</a>         raise ValueError(
#    <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1238'>1239</a>           "non-zero flags not allowed in calls to recv_into() on %s" %
#    <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1239'>1240</a>           self.__class__)
# -> <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1240'>1241</a>     return self.read(nbytes, buffer)
#    <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1241'>1242</a> else:
#    <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1242'>1243</a>     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1096'>1097</a> try:
#    <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1097'>1098</a>     if buffer is not None:
# -> <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1098'>1099</a>         return self._sslobj.read(len, buffer)
#    <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1099'>1100</a>     else:
#    <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py?line=1100'>1101</a>         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
yt = YouTube("https://www.youtube.com/watch?v=xviPQ07WfXI&t=534s")
print(yt.length)
resolutions = ["144p", "240p", "360p", "480p", "720p", "1080p", "1440p", "2160p", "4320p"]
resolutions.reverse()
# for r in iter(resolutions):
#     print(r, yt.streams.filter(res=r, subtype="mp4"))
#     print("-"*20)
# for i, stream in enumerate(yt.streams.filter().desc()):
#     print(i, stream)
#     # stream.download(output_path=".", filename=f"{i}-{stream.title}.mp4")
# print(yt.streams.filter(subtype="mp4").order_by('resolution').desc())
# print("-"*20)
streams = yt.streams.filter(subtype="mp4", only_audio=True).order_by('abr').desc() # Get best bitrate stream
streams[0].download()
# Out:
# 2466
# '/Users/warrenkrettek/Documents/projects/youmirror/26 The Gang Solves the North Korea Situation  The Always Sunny Podcast.mp4'

# %%
# things = [yt.author, yt.caption_tracks, yt.captions, yt.channel_id, yt.channel_url, yt.description, yt.fmt_streams, yt.keywords, yt.length, yt.metadata, yt.publish_date, yt.rating, yt.title, yt.views, yt.video_id, yt.js_url]

# too_big = [yt.vid_info, yt.js, yt.initial_data, yt.streaming_data]

# for t in things:
#     print(t)
#     print("-"*20)
# open("metadata.txt", "w").write(str(metadata))
v_stream = yt.streams.filter(res="2160p").first()
a_stream = yt.streams.filter(only_audio=True).first()
v_stream.download(filename="sunny_video.mp4")
a_stream.download(filename="sunny_audio.mp4")
# print(yt.streams)
# Out:
# '/Users/warrenkrettek/Documents/projects/youmirror/sunny_audio.mp4'
